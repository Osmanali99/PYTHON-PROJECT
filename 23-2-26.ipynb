# %%
square = lambda x: x ** 7
print(square(5))
# Out:
# 78125

# %%
even = lambda x: x % 2 == 0
print(even(4))
# Out:
# True

# %%
nums = [1, 2, 3, 4, 5]
squared_nums = list(map(lambda x: x ** 2, nums))
print(squared_nums)
# Out:
# [1, 4, 9, 16, 25]

# %%
square = lambda x: x ** 2
print(square(4))  # رزلٹ: 16
even = lambda x: x % 2 == 0
print(even(4))  # رزلٹ: True
# Out:
# 16
# True

# %%
pairs = [(1, 'one'), (2, 'two'), (3, 'three')]
sorted_pairs = sorted(pairs, key=lambda pair: pair[1])
print(sorted_pairs)  # رزلٹ: [(1, 'one'), (3, 'three'), (2, 'two')]
# Out:
# [(1, 'one'), (3, 'three'), (2, 'two')]

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort()
print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort(reverse = True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort(reverse = True)
print(thislist)
# Out:
# [100, 82, 65, 50, 23]

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.reverse()
print(thislist)
# Out:
# ['banana', 'pineapple', 'kiwi', 'mango', 'orange']

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.reverse()
print(thislist)
# Out:
# ['banana', 'pineapple', 'kiwi', 'mango', 'orange']

# %%
units = int(input("Enter the number of units consumed: "))
if units <= 100:
        bill = units * 13
elif units <= 200:
        bill = (100 * 13) + ((units - 100) * 15)
else:
        bill = (100 * 13) + (100 * 15) + ((units - 200) * 20)
print("The electricity bill is :PKR", bill)
# Out:
# The electricity bill is :PKR 780

# %%
#calulator
def add(x, y):
    return x + y
def subtract(x, y):
    return x - y
def multiply(x, y):
    return x * y
def divide(x, y):
    if y == 0:
        return "Error: Division by zero is not allowed."
    return x / y    
print("Select operation:")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")   
while True:
    choice = input("Enter choice(1/2/3/4): ")
    if choice in ('1', '2', '3', '4'):
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))
        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))
        elif choice == '2':
            print(num1, "-", num2, "=", subtract(num1, num2))
        elif choice == '3':
            print(num1, "*", num2, "=", multiply(num1, num2))
        elif choice == '4':
            print(num1, "/", num2, "=", divide(num1, num2))
        break
    else:
        print("Invalid Input")
# Out:
# Select operation:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 67.0 * 76.0 = 5092.0

# %%
for i in range(1,6):
  print
# Out:
#   Cell In[21], line 3
#     print("*", end="")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2
