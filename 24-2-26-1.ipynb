# %%
#create class hotel menu spy food swiming room and playground
def _init_(self):
    self.hotel_menu = "Hotel Menu"
    self.spy_food = "Spy Food"
    self.swimming_room = "Swimming Room"
    self.playground = "Playground"
class Hotel:
    def __init__(self):
        self.hotel_menu = "Hotel Menu"
        self.spy_food = "Spy Food"
        self.swimming_room = "Swimming Room"
        self.playground = "Playground"
        self.hotel_menu = "Hotel Menu"
        self.username="admin"
        self.password="password"
    

    
    def display_menu(self):
        print(self.hotel_menu)
    def display_spy_food(self):
        print(self.spy_food)    
    def display_swimming_room(self):
        print(self.swimming_room)
    def display_playground(self):
        print(self.playground)
    def login(self,username,password):
        if username == self.username and password == self.password:
            print("Login successful")
        else:
            print("Login failed")
hotel = Hotel()
hotel.display_menu()
hotel.display_spy_food()
hotel.display_swimming_room()
hotel.display_playground()
hotel.login("admin","password")
# Out:
# Hotel Menu
# Spy Food
# Swimming Room
# Playground
# Login successful

# %%
seter = Hotel()
seter.username = "new_admin"
seter.password = "new_password" 
seter.login("new_admin","new_password")
seter.display_menu()
# Out:
# Login successful
# Hotel Menu
