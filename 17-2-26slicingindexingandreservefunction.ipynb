# %%
print("hello wolrd" \
"")
# Out:
# hello wolrd

# %%
dict=["System Volume Information","hello","world"]
print(dict)
# Out:
# ['System Volume Information', 'hello', 'world']

# %%
print(dict[0][4])
# Out:
# e

# %%
print(dict[2])
# Out:
# world

# %%
print(dict[1])
# Out:
# hello

# %%
#create a progrma that inputs a data using users voice and print it on the screen
import speech_recognition as sr 
r = sr.Recognizer()
with sr.Microphone() as source:
    print("Say something!")
    audio = r.listen(source)
try:
    print("You said: " + r.recognize_google(audio))
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 #create a progrma that inputs a data using users voice and print it on the screen
# ----> 2 import speech_recognition as sr
#       3 r = sr.Recognizer()
#       4 with sr.Microphone() as source:
#
# ModuleNotFoundError: No module named 'speech_recognition'
