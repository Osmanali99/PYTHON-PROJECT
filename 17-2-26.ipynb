# %%
print("hello world")
# Out:
# hello world

# %%
a=30
b=20
if a<b:
    print(True)
else:
    print(False)
# Out:
# False

# %%
list1=[1,2,3,4,5,6,8,85,4,]
print(len(list1))
print("hello world")
# Out:
# 9
# hello world

# %%
txt = "Hello my FRIENDS"

x = txt.lower()

print(x)
# Out:
# hello my friends

# %%
txt = "Hello my FRIENDS"

x = txt.upper()

print(x)
# Out:
# HELLO MY FRIENDS

# %%
txt = "I like bananas"

x = txt.replace("bananas", "apples")

print(x)
# Out:
# I like apples

# %%
thisdict = {
  "brand": "Ford",
  "x": "Mustang",
  "year": 1964
}
if "x" in thisdict:
  print("Yes, 'x' is one of the keys in the thisdict dictionary")
# Out:
# Yes, 'x' is one of the keys in the thisdict dictionary

# %%
x = 1
y = 35656222554887711.0
z = -3255522

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
str(70)
# Out:
# '70'

# %%
int("100")
# Out:
# 100

# %%
x = input("Type a number: ")
y = input("Type another number: ")

sum = int(x) + int(y)

print("The sum is: ", sum)
# Out:
# The sum is:  99906998

# %%
##hjkhkhkhkllkjjlkjlk

# %%
>>> bool(0)
True
>>> bool(1)
False
# Out:
# False

# %%
>>> bool(0)
False
>>> bool(1)
True
# Out:
# True

# %%
my_list = [1, 2, 2, 3, 4, 3, 5]
my_set = set(my_list)

print(my_set)
# Output: {1, 2, 3, 4, 5}  (Note: the order may vary as sets are unordered)
# Out:
# {1, 2, 3, 4, 5}

# %%
# Create a sample set
fruits = {"apple", "banana", "cherry"}

# Check for the membership of an element
print("banana" in fruits)  # Output: True
print("grape" in fruits)   # Output: False
# Out:
# True
# False
