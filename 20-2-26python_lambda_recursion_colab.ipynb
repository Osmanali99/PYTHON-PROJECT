# %% [markdown]
# # Python Practice: While Loop, Functions, Variable Scope, Lambda, Recursion
# This notebook contains **10 code examples for each topic** with **2-line explanations**.
# Run each cell in Google Colab to see the output.

# %% [markdown]
# ## Lambda Functions — 10 Examples

# %%
add = lambda a, b: a + b
print(add(2, 3))
# Out:
# 5

# %% [markdown]
# Anonymous function that adds two numbers.
# Defined in a single line using lambda.

# %%
square = lambda x: x*x
print(square(4))
# Out:
# 16

# %% [markdown]
# Computes square of a number.
# No need for def keyword.

# %%
even = lambda n: n % 2 == 0
print(even(6))
# Out:
# True

# %% [markdown]
# Returns True if number is even.
# Useful for quick checks.

# %%
nums = [1,2,3]
print(list(map(lambda x: x*2, nums)))
# Out:
# [2, 4, 6]

# %% [markdown]
# Applies lambda to each list element.
# Map returns transformed values.

# %%
nums = [1,2,3,4]
print(list(filter(lambda x: x%2==0, nums)))
# Out:
# [2, 4]

# %% [markdown]
# Filters only even numbers.
# Filter keeps elements meeting condition.

# %%
pairs = [(1,3),(2,1),(5,2)]
pairs.sort(key=lambda x: x[1])
print(pairs)
# Out:
# [(2, 1), (5, 2), (1, 3)]

# %% [markdown]
# Sorts list using second element.
# Lambda used as key function.

# %%
mul = lambda a,b,c: a*b*c
print(mul(2,3,4))
# Out:
# 24

# %% [markdown]
# Lambda with multiple arguments.
# Returns product of inputs.

# %%
f = lambda: "Hello"
print(f())
# Out:
# Hello

# %% [markdown]
# Lambda with no parameters.
# Returns a constant value.

# %%
nums = [5,1,4]
print(sorted(nums, key=lambda x: -x))
# Out:
# [5, 4, 1]

# %% [markdown]
# Sorts list in descending order.
# Negative key reverses order.

# %%
length = lambda s: len(s)
print(length("Python"))
# Out:
# 6

# %% [markdown]
# Returns length of string.
# Simple one-line function.

# %% [markdown]
# ## Recursion — 10 Examples

# %%
def fact(n):
    if n == 1:
        return 1
    return n * fact(n-1)
print(fact(5))
# Out:
# 120

# %% [markdown]
# Computes factorial recursively.
# Function calls itself with smaller input.

# %%
def sum_n(n):
    if n == 0:
        return 0
    return n + sum_n(n-1)
print(sum_n(5))
# Out:
# 15

# %% [markdown]
# Finds sum of first n numbers.
# Adds current value each call.

# %%
def count_down(n):
    if n == 0:
        return
    print(n)
    count_down(n-1)
count_down(3)
# Out:
# 3
# 2
# 1

# %% [markdown]
# Prints numbers in reverse order.
# Stops when base case reached.

# %%
def fib(n):
    if n <= 1:
        return n
    return fib(n-1) + fib(n-2)
print(fib(6))
# Out:
# 8

# %% [markdown]
# Computes Fibonacci number.
# Uses two recursive calls.

# %%
def power(a, b):
    if b == 0:
        return 1
    return a * power(a, b-1)
print(power(2,3))
# Out:
# 8

# %% [markdown]
# Calculates exponent recursively.
# Multiplies base repeatedly.

# %%
def reverse(s):
    if s == "":
        return ""
    return reverse(s[1:]) + s[0]
print(reverse("abc"))
# Out:
# cba

# %% [markdown]
# Reverses a string using recursion.
# Moves first char to end each call.

# %%
def gcd(a,b):
    if b == 0:
        return a
    return gcd(b, a%b)
print(gcd(12,8))
# Out:
# 4

# %% [markdown]
# Finds greatest common divisor.
# Uses Euclid's recursive method.

# %%
def digits(n):
    if n < 10:
        return 1
    return 1 + digits(n//10)
print(digits(1234))
# Out:
# 4

# %% [markdown]
# Counts digits of a number.
# Removes last digit each step.

# %%
def print_list(lst):
    if not lst:
        return
    print(lst[0])
    print_list(lst[1:])
print_list([1,2,3])
# Out:
# 1
# 2
# 3

# %%
def sum_list(lst):
    if not lst:
        return 0
    return lst[0] + sum_list(lst[1:])
print(sum_list([1,2,3]))
# Out:
# 6

# %%
fibonacci = lambda n: n if n <= 1 else fibonacci(n-1) + fibonacci(n-2)
print(fibonacci(6))
# Out:
# 8

# %%
x=10
try:
  print(x)
except:
  print("An exception occurred")
# Out:
# 10

# %%
try:
  
  print(x)
except NameError:
  print("Variable x is not defined")
except:
  print("Something else went wrong")
# Out:
# 13

# %%
try:
  print(x)
except NameError:
  print("Variable x is not defined")
# Out:
# 13

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong
